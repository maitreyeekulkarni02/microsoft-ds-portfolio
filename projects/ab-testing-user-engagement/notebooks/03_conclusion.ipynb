# %% [markdown]
# # 03 - Conclusion
# - Interpret statistical results

# %%
if p_value < 0.05:
    print("Reject H0: Feature change significantly improved engagement")
else:
    print("Fail to reject H0: No significant effect detected")
# Out:
# Reject H0: Feature change significantly improved engagement
