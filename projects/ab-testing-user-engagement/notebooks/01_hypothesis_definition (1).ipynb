# %% [markdown]
# # 01 - Hypothesis Definition
# - Define control and treatment groups
# - Define metric (e.g., click-through rate)

# %%
import pandas as pd

# Example data
df = pd.DataFrame({
    'user_id': range(1,11),
    'group': ['control']*5 + ['treatment']*5,
    'engagement': [5,6,5,4,5,7,8,7,6,8]
})
df.head()
# Out:
#    user_id    group  engagement
# 0        1  control           5
# 1        2  control           6
# 2        3  control           5
# 3        4  control           4
# 4        5  control           5
