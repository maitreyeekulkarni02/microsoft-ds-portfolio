# %%
# Hypothesis Definition

## Objective
Define control and treatment groups for A/B testing.

## Hypothesis
- Null Hypothesis (H0): Feature change does not affect engagement
- Alternative Hypothesis (H1): Feature change improves engagement

# %%
import pandas as pd

df = pd.DataFrame({
    'user_id': range(1,11),
    'group': ['control']*5 + ['treatment']*5,
    'engagement': [5,6,5,4,5,7,8,7,6,8]
})

df
